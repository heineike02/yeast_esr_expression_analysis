# %%
import pandas as pd
from intermine.webservice import Service
data_processing_dir = '/home/heineike/github/expression_broad_data/expression_data/'
from intermine.webservice import Service
service = Service("https://yeastmine.yeastgenome.org:443/yeastmine/service", token = "L155qee34elf4eY1a9H5")

# %%
kl_sc_PKA_data = pd.read_pickle(data_processing_dir + "20170817_klscpka/kl_sc_PKA_data_SDC_t40_AsMinvAsPlus.pkl")

# %%
#Highlight hits that are statistically significant for K.Lactis 

#Add column which highlights only pvalues below a threshold

#should eventually have a principled way of picking these
pthreshold_KL = 10e-5
pthreshold_SC = 10e-9

# stre_eq1 = [kl_gene for kl_gene, n in jso_prom_hits_kl_hitcount.items() if n==1]
# stre_gt1 = [kl_gene for kl_gene, n in jso_prom_hits_kl_hitcount.items() if n>1]

kl_sc_PKA_data_klsig = kl_sc_PKA_data[kl_sc_PKA_data['padj_KL'] < pthreshold_KL]
kl_sc_PKA_data_scsig = kl_sc_PKA_data[kl_sc_PKA_data['padj_SC'] < pthreshold_SC]

klscsig_ind = set(kl_sc_PKA_data_klsig.index)&set(kl_sc_PKA_data_scsig.index)
klsig_scunsig_ind = set(kl_sc_PKA_data_klsig.index)-klscsig_ind
scsig_klunsig_ind = set(kl_sc_PKA_data_scsig.index)-klscsig_ind
unsig_ind = set(kl_sc_PKA_data.index)-(set(kl_sc_PKA_data_klsig.index)|set(kl_sc_PKA_data_scsig.index))

print([len(klscsig_ind),len(klsig_scunsig_ind),len(scsig_klunsig_ind),len(unsig_ind)])

kl_sc_PKA_data_klsig_scunsig = kl_sc_PKA_data.loc[list(klsig_scunsig_ind)]
kl_sc_PKA_data_scsig_klunsig = kl_sc_PKA_data.loc[list(scsig_klunsig_ind)]
kl_sc_PKA_data_klscsig = kl_sc_PKA_data.loc[list(klscsig_ind)]
kl_sc_PKA_data_unsig = kl_sc_PKA_data.loc[list(unsig_ind)]

# print([len(kl_sc_PKA_data_klscsig),len(kl_sc_PKA_data_klsig_scunsig),len(kl_sc_PKA_data_scsig_klunsig),len(kl_sc_PKA_data_unsig)])
# Out:
# [462, 486, 319, 3709]

# %%
" ".join(kl_sc_PKA_data_scsig[kl_sc_PKA_data_scsig['PKA(AS)+1NMPP1_SC']>0]['sc_genename'])
# Out:
# 'YKR076W YOR163W YNL015W YNL305C YOR176W YPR160W YPR098C YDR357C YPR155C YJL161W YOL071W YKR049C YLR178C YJL057C YBR280C YDL149W YOR223W YHR087W YML128C YPL222W YOL032W YJL068C YAL060W YMR169C YMR087W YIL155C YHL021C YML004C YOR161C YBR285W YHL036W YJR036C YPR026W YKL107W YLR149C YJL153C YGR255C YCL039W YOL096C YER079W YKL086W YOL048C YDR262W YFR045W YHR176W YJL020C YKL065W-A YOR367W YCR061W YBR126C YIL160C YOR374W YHR075C YMR196W YKL067W YMR107W YPL004C YBR056W YOL084W YPL196W YDR100W YDR231C YPL154C YFL014W YJL016W YBR269C YLR345W YIL136W YCL038C YDL020C YJL042W YPL003W YBR149W YCR004C YOR292C YGL227W YBL064C YDL078C YIL124W YML070W YKL085W YLL023C YBR062C YKL151C YPR151C YHR140W YKR011C YKL103C YHR104W YNL115C YDL126C YMR110C YDL124W YKL142W YBR026C YIL017C YOR228C YNL274C YBR230C YGL037C YLR438W YNL242W YBL078C YHR008C YNL200C YOR289W YBR053C YNL134C YIL065C YBL086C YGR088W YOL065C YEL012W YLL039C YER142C YDR171W YEL011W YPL123C YPL109C YKL193C YGL141W YDL169C YBR072W YBR286W YBR006W YIL033C YML054C YAL061W YGR236C YMR170C YGR174C YCR011C YOR285W YMR280C YCR045C YPL206C YLR070C YNL237W YFR003C YDR379C-A YDR070C YMR250W YMR135C YJL132W YIL108W YGL006W YJR008W YIL107C YKL162C YGL205W YJL163C YER182W YPL113C YDL110C YLR152C YIL055C YIL101C YOL013C YML042W YGR194C YOR152C YJL185C YIL087C YHR138C YMR297W YPL006W YJR096W YNL202W YKL010C YOR036W YDR074W YLL026W YAL008W YLR241W YGR130C YPL186C YBL029C-A YGR281W YPL247C YNL321W YOR215C YLR284C YNL100W YIR014W YNL045W YGR052W YKL121W YMR031C YBR001C YCL040W YDR516C YDR018C YER096W YGR256W YGR254W YHR106W YAL028W YLR177W YDR055W YBL075C YER103W YHR160C YFR015C YLR258W YPR149W YHR016C YDL204W YAL034C YKL141W YMR118C YEL060C YER119C YBL101C YPR030W YDL085W YHR096C YMR271C YNR002C YBR037C YDR272W YAL030W YER054C YER067W YNL055C YBR147W YLR270W YOR173W YJL079C YNL270C YHR097C YIL111W YNL014W YGR248W YNR001C YNL194C YFR053C YDR034W-B YNR014W YFR017C YLR248W YAL017W YLR080W YJL164C YPR172W YPL230W YBR052C YDR032C YJR059W YEL041W YOR185C YMR175W YPL223C YGR008C YLR327C YDL130W-A YGR043C YIL113W YBR241C YGL104C YGR209C YFL042C YCL035C YDR513W YCL048W-A YGL229C YNL195C YDL223C YDR436W YML100W YMR261C YIL066C YJL045W YDR085C YDR475C YOR019W YDR059C YBR214W YKR058W YER101C YKL091C YLR356W YKL035W YGR243W YLR164W YDL022W YNR034W-A YDL019C YER150W YDR453C YBR117C YLR174W YMR105C YGR070W YER039C YAL062W YBR169C YDL021W YBR183W YEL039C'

# %%
#Generate a list of all genes in KL_SC_PKA_data and add as a list in intermine named
#20170905_kl_sc_PKA_data_genes 
#We can then make subsets programmatically using the API

#I ran this command: 
#" ".join(kl_sc_PKA_data['sc_genename'])

#Then copied and pasted the output into the yeastmine build query list. 

#The following items were not found in SGD: 
#Scer_YGOB_YDR134C Scer_RDN18-1 Scer_YGOB_SDC25 Scer_RDN25-1 Scer_RDN58-1 Scer_YGOB_Anc_7.495 Scer_YGOB_ADL119W Scer_RDN5-1

#I wonder if I could do this just using something like this: query.add_constraint("Gene", "LOOKUP", ["YNL323W","YIL093C",...])

# %%
#(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']>0) & (kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']>0)


#The one gene that is significant for both, but up in SC and down in kl. 
#set(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']>0)]['sc_genename'])-set(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']>0) & (kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']>0)]['sc_genename'])
#HEF3 {'YNL014W'}

a = set(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']<0)]['sc_genename'])
b = set(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']<0)]['sc_genename'])
c = set(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']<0) & (kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']<0)]['sc_genename'])

#YJL208C
#NUC1 up in KL and down in SC
#mintochondrial nuclease.

# %%
mitophagy_list = ['YCR079W','YDL113C','YFR021W','YGR049W','YIL146C','YJL036W','YLL042C','YLR423C','YNL223W','YNR007C']
mito_disassembly_list = ['YCR079W','YDL113C','YFR021W','YGR049W','YIL146C','YJL036W','YLL042C','YLR423C','YNL223W','YNR007C']
lipid_catabolic_list = ['YAL051W','YCR068W','YDR036C','YDR058C','YGL010W','YKR009C','YKR089C','YMR008C','YMR313C','YOL011W','YOR059C','YOR081C','YOR084W','YOR363C','YPR001W','YPR002W','YPR006C']
kl_sc_PKA_data[kl_sc_PKA_data['sc_genename'].isin(lipid_catabolic_list)]
#kl_sc_PKA_data_scsig_klunsig
# Out:
#       N SCer Orthologs   kl_genename sc_genename  PKA(AS)+1NMPP1_KL  \
# 21                   1  KLLA0F18678g     YDR036C           2.075350
# 336                  1  KLLA0E13905g     YPR006C           2.314233
# 620                  1  KLLA0F16423g     YOR059C           1.650792
# 1088                 1  KLLA0C02739g     YDR058C           1.690946
# 1174                 1  KLLA0A10175g     YMR313C           2.402741
# 1450                 1  KLLA0A05005g     YGL010W           2.449851
# 1587                 1  KLLA0E13091g     YOR084W           3.015737
# 2668                 1  KLLA0E13817g     YKR009C           3.455427
# 2725                 1  KLLA0E14213g     YPR002W           4.312088
# 2757                 1  KLLA0C08679g     YCR068W           2.380969
# 3722                 1  KLLA0E14235g     YPR001W           4.851200
# 4416                 2  KLLA0A07557g     YKR089C           2.458184
# 4417                 2  KLLA0A07557g     YOR081C           2.458184
# 4614                 2  KLLA0A03443g     YAL051W           1.629952
# 4615                 2  KLLA0A03443g     YOR363C           1.629952
# 4654                 2  KLLA0C05940g     YMR008C           2.148433
# 4655                 2  KLLA0C05940g     YOL011W           2.148433
#
#            padj_KL  PKA(AS)+1NMPP1_SC       padj_SC SC_common_name
# 21    2.885098e-07           0.261295  5.984839e-01           EHD3
# 336   2.376141e-05           1.245965  3.071610e-04           ICL2
# 620   6.436999e-05           1.377572  3.806161e-05           LPL1
# 1088  2.639785e-06           2.218048  6.700189e-06           TGL2
# 1174  2.263349e-08           1.010312  3.231624e-03           TGL3
# 1450  3.105022e-10           2.476848  3.041543e-08           MPO1
# 1587  1.038063e-08           0.305030  5.344210e-01           LPX1
# 2668  3.535806e-17           2.397845  3.332038e-06           FOX2
# 2725  1.377854e-05          -1.285601  3.891092e-01           PDH1
# 2757  2.569959e-08           1.656607  6.587939e-01          ATG15
# 3722  1.081647e-08           2.257085  4.480652e-02           CIT3
# 4416  4.243260e-11           0.932734  3.385038e-03           TGL4
# 4417  4.243260e-11           0.619536  2.682369e-01           TGL5
# 4614  3.213289e-06           1.123080  1.130482e-02           OAF1
# 4615  3.213289e-06           1.110512  5.039133e-01           PIP2
# 4654  4.820164e-09          -0.153663  7.317968e-01           PLB1
# 4655  4.820164e-09          -0.743361  1.157268e-01           PLB3

# %%
a = list(kl_sc_PKA_data_klsig_scunsig[kl_sc_PKA_data_klsig_scunsig['PKA(AS)+1NMPP1_KL']>0]['sc_genename']).append('YJL208C')
a[-3:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-258-0e5da148e624> in <module>()
#       1 a = list(kl_sc_PKA_data_klsig_scunsig[kl_sc_PKA_data_klsig_scunsig['PKA(AS)+1NMPP1_KL']>0]['sc_genename']).append('YJL208C')
# ----> 2 a[-3:]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#Generate Query for all kl_sc_PKA_data genes

# Get a new query on the class (table) you will be querying:
query_all = service.new_query("Gene")

# The view specifies the output columns
query_all.add_view(
    "primaryIdentifier", "secondaryIdentifier", "organism.shortName", "symbol",
    "name"
)

# You can edit the constraint values below
query_all.add_constraint("Gene", "IN", "20170509_kl_sc_PKA_data_genes", code = "A")

# Uncomment and edit the code below to specify your own custom logic:
# query.set_logic("A")

#gene_id_list = [str(row["id"] for row in query.rows()]

#type(gene_id_list[0])

# query_list = list(query)

# for row in query_list:     #query.rows():
#     print(row["primaryIdentifier"], row["secondaryIdentifier"], row["organism.shortName"], \
#         row["symbol"], row["name"], row["id"])
# Out:
# <ListConstraint: Gene IN 20170509_kl_sc_PKA_data_genes>

# %%
#For each set of genes
# gene_sets = [('klsig','act'),
#             ('scsig','act'),
#             ('klscsig','act'),
#             ('klsig','rep'),
#             ('scsig','rep'),
#             ('klscsig','rep')]

#Add in the one gene that is significant for both but repressed in SC and activated in KL. 
klsig_act_genes = list(kl_sc_PKA_data_klsig_scunsig[kl_sc_PKA_data_klsig_scunsig['PKA(AS)+1NMPP1_KL']>0]['sc_genename'])
klsig_act_genes.append('YJL208C')

#Add in the one gene that is significant for both but activated in SC and repressed in KL.
klsig_rep_genes = list(kl_sc_PKA_data_klsig_scunsig[kl_sc_PKA_data_klsig_scunsig['PKA(AS)+1NMPP1_KL']<0]['sc_genename'])
klsig_rep_genes.append('YNL014W')

#Add in the one gene that is significant for both but activated in SC and repressed in KL.
scsig_act_genes = list(kl_sc_PKA_data_scsig_klunsig[kl_sc_PKA_data_scsig_klunsig['PKA(AS)+1NMPP1_SC']>0]['sc_genename'])
scsig_act_genes.append('YNL014W')

#Add in the one gene that is significant for both but repressed in SC and activated in KL. 
scsig_rep_genes = list(kl_sc_PKA_data_scsig_klunsig[kl_sc_PKA_data_scsig_klunsig['PKA(AS)+1NMPP1_SC']<0]['sc_genename'])
scsig_rep_genes.append('YJL208C')

gene_sets = ['klsig_act', 'klsig_rep','scsig_act','scsig_rep','klscsig_act','klscsig_rep']

gene_set_dict = {'klsig_act': klsig_act_genes,
                 'klsig_rep': klsig_rep_genes,
                 'scsig_act': scsig_act_genes,
                 'scsig_rep': scsig_rep_genes,
                 'klscsig_act': list(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']>0) & (kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']>0)]['sc_genename']),
                 'klscsig_rep': list(kl_sc_PKA_data_klscsig[(kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_SC']<0) & (kl_sc_PKA_data_klscsig['PKA(AS)+1NMPP1_KL']<0)]['sc_genename'])
                }

missing_genes = ['Scer_YGOB_YDR134C', 'Scer_RDN18-1', 
                 'Scer_YGOB_SDC25', 'Scer_RDN25-1', 
                 'Scer_RDN58-1', 'Scer_YGOB_Anc_7.495', 
                 'Scer_YGOB_ADL119W', 'Scer_RDN5-1']

pval_cutoff = 0.01

for gene_set in gene_sets: 
    print(gene_set)
    gene_set_list = gene_set_dict[gene_set]
    
    #filter out missing genes 
    print("The following missing genes are filtered out:")
    print(set(gene_set_list) & set(missing_genes))
    gene_set_list_filtered = list(set(gene_set_list)-set(missing_genes))
    new_query = query_all.clone()
    
    #subset query based on desired gene set
    new_query.add_constraint("Gene.secondaryIdentifier", "ONE OF", gene_set_list_filtered)
    
    #Generate a list
    new_list = service.create_list(new_query.select('Gene.id'), "Gene", name = "20170905" + gene_set)
    
    #Run Go enrichment on the list
    results = new_list.calculate_enrichment('go_enrichment_for_gene')
    results_list = list(results)    
    for result in results_list: 
        print(result)
        if result['p-value']<pval_cutoff:
            print(result)
            print(result)
            
    #Given a P-value cutoff
    # Save the go term 
    # Save the contingency table
    # Save the related genes
# Out:
# klsig_act
# The following missing genes are filtered out:
# {'Scer_YGOB_SDC25'}
# {'description': 'lipid catabolic process', 'p-value': 1.4470773067871862e-06, 'matches': 16, 'identifier': 'GO:0016042', 'populationAnnotationCount': 61}
# {'description': 'lipid catabolic process', 'p-value': 1.4470773067871862e-06, 'matches': 16, 'identifier': 'GO:0016042', 'populationAnnotationCount': 61}
# {'description': 'lipid catabolic process', 'p-value': 1.4470773067871862e-06, 'matches': 16, 'identifier': 'GO:0016042', 'populationAnnotationCount': 61}
# {'description': 'cellular lipid catabolic process', 'p-value': 2.2382440433077777e-06, 'matches': 14, 'identifier': 'GO:0044242', 'populationAnnotationCount': 46}
# {'description': 'cellular lipid catabolic process', 'p-value': 2.2382440433077777e-06, 'matches': 14, 'identifier': 'GO:0044242', 'populationAnnotationCount': 46}
# {'description': 'cellular lipid catabolic process', 'p-value': 2.2382440433077777e-06, 'matches': 14, 'identifier': 'GO:0044242', 'populationAnnotationCount': 46}
# {'description': 'catabolic process', 'p-value': 0.0006057912753930454, 'matches': 55, 'identifier': 'GO:0009056', 'populationAnnotationCount': 745}
# {'description': 'catabolic process', 'p-value': 0.0006057912753930454, 'matches': 55, 'identifier': 'GO:0009056', 'populationAnnotationCount': 745}
# {'description': 'catabolic process', 'p-value': 0.0006057912753930454, 'matches': 55, 'identifier': 'GO:0009056', 'populationAnnotationCount': 745}
# {'description': 'organic substance catabolic process', 'p-value': 0.001216548343839346, 'matches': 54, 'identifier': 'GO:1901575', 'populationAnnotationCount': 740}
# {'description': 'organic substance catabolic process', 'p-value': 0.001216548343839346, 'matches': 54, 'identifier': 'GO:1901575', 'populationAnnotationCount': 740}
# {'description': 'organic substance catabolic process', 'p-value': 0.001216548343839346, 'matches': 54, 'identifier': 'GO:1901575', 'populationAnnotationCount': 740}
# {'description': 'single-organism process', 'p-value': 0.0013150219291881273, 'matches': 160, 'identifier': 'GO:0044699', 'populationAnnotationCount': 3436}
# {'description': 'single-organism process', 'p-value': 0.0013150219291881273, 'matches': 160, 'identifier': 'GO:0044699', 'populationAnnotationCount': 3436}
# {'description': 'single-organism process', 'p-value': 0.0013150219291881273, 'matches': 160, 'identifier': 'GO:0044699', 'populationAnnotationCount': 3436}
# {'description': 'cellular lipid metabolic process', 'p-value': 0.0019399188316196465, 'matches': 31, 'identifier': 'GO:0044255', 'populationAnnotationCount': 318}
# {'description': 'cellular lipid metabolic process', 'p-value': 0.0019399188316196465, 'matches': 31, 'identifier': 'GO:0044255', 'populationAnnotationCount': 318}
# {'description': 'cellular lipid metabolic process', 'p-value': 0.0019399188316196465, 'matches': 31, 'identifier': 'GO:0044255', 'populationAnnotationCount': 318}
# {'description': 'mitophagy', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0000422', 'populationAnnotationCount': 37}
# {'description': 'mitophagy', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0000422', 'populationAnnotationCount': 37}
# {'description': 'mitophagy', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0000422', 'populationAnnotationCount': 37}
# {'description': 'mitochondrion disassembly', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0061726', 'populationAnnotationCount': 37}
# {'description': 'mitochondrion disassembly', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0061726', 'populationAnnotationCount': 37}
# {'description': 'mitochondrion disassembly', 'p-value': 0.002674670085493186, 'matches': 10, 'identifier': 'GO:0061726', 'populationAnnotationCount': 37}
# {'description': 'cellular catabolic process', 'p-value': 0.008169879075210076, 'matches': 47, 'identifier': 'GO:0044248', 'populationAnnotationCount': 641}
# {'description': 'cellular catabolic process', 'p-value': 0.008169879075210076, 'matches': 47, 'identifier': 'GO:0044248', 'populationAnnotationCount': 641}
# {'description': 'cellular catabolic process', 'p-value': 0.008169879075210076, 'matches': 47, 'identifier': 'GO:0044248', 'populationAnnotationCount': 641}
# {'description': 'glycerolipid catabolic process', 'p-value': 0.00903333417815859, 'matches': 6, 'identifier': 'GO:0046503', 'populationAnnotationCount': 12}
# {'description': 'glycerolipid catabolic process', 'p-value': 0.00903333417815859, 'matches': 6, 'identifier': 'GO:0046503', 'populationAnnotationCount': 12}
# {'description': 'glycerolipid catabolic process', 'p-value': 0.00903333417815859, 'matches': 6, 'identifier': 'GO:0046503', 'populationAnnotationCount': 12}
# {'description': 'lipid metabolic process', 'p-value': 0.01018069081840652, 'matches': 31, 'identifier': 'GO:0006629', 'populationAnnotationCount': 343}
# {'description': 'neutral lipid catabolic process', 'p-value': 0.01683980494503397, 'matches': 5, 'identifier': 'GO:0046461', 'populationAnnotationCount': 8}
# {'description': 'single-organism metabolic process', 'p-value': 0.018074874944907327, 'matches': 84, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'fatty acid metabolic process', 'p-value': 0.03085448833196635, 'matches': 12, 'identifier': 'GO:0006631', 'populationAnnotationCount': 69}
# klsig_rep
# The following missing genes are filtered out:
# set()
# {'description': 'organonitrogen compound biosynthetic process', 'p-value': 1.1794237425064692e-38, 'matches': 147, 'identifier': 'GO:1901566', 'populationAnnotationCount': 1159}
# {'description': 'organonitrogen compound biosynthetic process', 'p-value': 1.1794237425064692e-38, 'matches': 147, 'identifier': 'GO:1901566', 'populationAnnotationCount': 1159}
# {'description': 'organonitrogen compound biosynthetic process', 'p-value': 1.1794237425064692e-38, 'matches': 147, 'identifier': 'GO:1901566', 'populationAnnotationCount': 1159}
# {'description': 'mitochondrial translation', 'p-value': 3.480884688834449e-35, 'matches': 59, 'identifier': 'GO:0032543', 'populationAnnotationCount': 171}
# {'description': 'mitochondrial translation', 'p-value': 3.480884688834449e-35, 'matches': 59, 'identifier': 'GO:0032543', 'populationAnnotationCount': 171}
# {'description': 'mitochondrial translation', 'p-value': 3.480884688834449e-35, 'matches': 59, 'identifier': 'GO:0032543', 'populationAnnotationCount': 171}
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.677669858123977e-34, 'matches': 156, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.677669858123977e-34, 'matches': 156, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.677669858123977e-34, 'matches': 156, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'amide biosynthetic process', 'p-value': 1.9146926650792372e-30, 'matches': 114, 'identifier': 'GO:0043604', 'populationAnnotationCount': 820}
# {'description': 'amide biosynthetic process', 'p-value': 1.9146926650792372e-30, 'matches': 114, 'identifier': 'GO:0043604', 'populationAnnotationCount': 820}
# {'description': 'amide biosynthetic process', 'p-value': 1.9146926650792372e-30, 'matches': 114, 'identifier': 'GO:0043604', 'populationAnnotationCount': 820}
# {'description': 'translation', 'p-value': 1.4107362419705543e-29, 'matches': 109, 'identifier': 'GO:0006412', 'populationAnnotationCount': 766}
# {'description': 'translation', 'p-value': 1.4107362419705543e-29, 'matches': 109, 'identifier': 'GO:0006412', 'populationAnnotationCount': 766}
# {'description': 'translation', 'p-value': 1.4107362419705543e-29, 'matches': 109, 'identifier': 'GO:0006412', 'populationAnnotationCount': 766}
# {'description': 'peptide biosynthetic process', 'p-value': 2.3180371717093495e-29, 'matches': 109, 'identifier': 'GO:0043043', 'populationAnnotationCount': 770}
# {'description': 'peptide biosynthetic process', 'p-value': 2.3180371717093495e-29, 'matches': 109, 'identifier': 'GO:0043043', 'populationAnnotationCount': 770}
# {'description': 'peptide biosynthetic process', 'p-value': 2.3180371717093495e-29, 'matches': 109, 'identifier': 'GO:0043043', 'populationAnnotationCount': 770}
# {'description': 'peptide metabolic process', 'p-value': 2.4612613479863283e-27, 'matches': 109, 'identifier': 'GO:0006518', 'populationAnnotationCount': 809}
# {'description': 'peptide metabolic process', 'p-value': 2.4612613479863283e-27, 'matches': 109, 'identifier': 'GO:0006518', 'populationAnnotationCount': 809}
# {'description': 'peptide metabolic process', 'p-value': 2.4612613479863283e-27, 'matches': 109, 'identifier': 'GO:0006518', 'populationAnnotationCount': 809}
# {'description': 'cellular amide metabolic process', 'p-value': 3.0863243964644438e-27, 'matches': 114, 'identifier': 'GO:0043603', 'populationAnnotationCount': 884}
# {'description': 'cellular amide metabolic process', 'p-value': 3.0863243964644438e-27, 'matches': 114, 'identifier': 'GO:0043603', 'populationAnnotationCount': 884}
# {'description': 'cellular amide metabolic process', 'p-value': 3.0863243964644438e-27, 'matches': 114, 'identifier': 'GO:0043603', 'populationAnnotationCount': 884}
# {'description': 'nitrogen compound metabolic process', 'p-value': 1.0493371018984419e-22, 'matches': 210, 'identifier': 'GO:0006807', 'populationAnnotationCount': 2993}
# {'description': 'nitrogen compound metabolic process', 'p-value': 1.0493371018984419e-22, 'matches': 210, 'identifier': 'GO:0006807', 'populationAnnotationCount': 2993}
# {'description': 'nitrogen compound metabolic process', 'p-value': 1.0493371018984419e-22, 'matches': 210, 'identifier': 'GO:0006807', 'populationAnnotationCount': 2993}
# {'description': 'gene expression', 'p-value': 1.8408667104081404e-16, 'matches': 163, 'identifier': 'GO:0010467', 'populationAnnotationCount': 2111}
# {'description': 'gene expression', 'p-value': 1.8408667104081404e-16, 'matches': 163, 'identifier': 'GO:0010467', 'populationAnnotationCount': 2111}
# {'description': 'gene expression', 'p-value': 1.8408667104081404e-16, 'matches': 163, 'identifier': 'GO:0010467', 'populationAnnotationCount': 2111}
# {'description': 'cellular biosynthetic process', 'p-value': 8.890527000236657e-16, 'matches': 176, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'cellular biosynthetic process', 'p-value': 8.890527000236657e-16, 'matches': 176, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'cellular biosynthetic process', 'p-value': 8.890527000236657e-16, 'matches': 176, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'organic substance biosynthetic process', 'p-value': 2.2662043939456823e-15, 'matches': 176, 'identifier': 'GO:1901576', 'populationAnnotationCount': 2449}
# {'description': 'organic substance biosynthetic process', 'p-value': 2.2662043939456823e-15, 'matches': 176, 'identifier': 'GO:1901576', 'populationAnnotationCount': 2449}
# {'description': 'organic substance biosynthetic process', 'p-value': 2.2662043939456823e-15, 'matches': 176, 'identifier': 'GO:1901576', 'populationAnnotationCount': 2449}
# {'description': 'cellular nitrogen compound metabolic process', 'p-value': 4.390303470897839e-15, 'matches': 190, 'identifier': 'GO:0034641', 'populationAnnotationCount': 2798}
# {'description': 'cellular nitrogen compound metabolic process', 'p-value': 4.390303470897839e-15, 'matches': 190, 'identifier': 'GO:0034641', 'populationAnnotationCount': 2798}
# {'description': 'cellular nitrogen compound metabolic process', 'p-value': 4.390303470897839e-15, 'matches': 190, 'identifier': 'GO:0034641', 'populationAnnotationCount': 2798}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 9.335390019870767e-15, 'matches': 148, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 9.335390019870767e-15, 'matches': 148, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 9.335390019870767e-15, 'matches': 148, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'biosynthetic process', 'p-value': 1.2825055332721666e-14, 'matches': 176, 'identifier': 'GO:0009058', 'populationAnnotationCount': 2483}
# {'description': 'biosynthetic process', 'p-value': 1.2825055332721666e-14, 'matches': 176, 'identifier': 'GO:0009058', 'populationAnnotationCount': 2483}
# {'description': 'biosynthetic process', 'p-value': 1.2825055332721666e-14, 'matches': 176, 'identifier': 'GO:0009058', 'populationAnnotationCount': 2483}
# {'description': 'cellular metabolic process', 'p-value': 1.0609061549973035e-10, 'matches': 225, 'identifier': 'GO:0044237', 'populationAnnotationCount': 3993}
# {'description': 'cellular metabolic process', 'p-value': 1.0609061549973035e-10, 'matches': 225, 'identifier': 'GO:0044237', 'populationAnnotationCount': 3993}
# {'description': 'cellular metabolic process', 'p-value': 1.0609061549973035e-10, 'matches': 225, 'identifier': 'GO:0044237', 'populationAnnotationCount': 3993}
# {'description': 'primary metabolic process', 'p-value': 2.074802823938643e-10, 'matches': 221, 'identifier': 'GO:0044238', 'populationAnnotationCount': 3885}
# {'description': 'primary metabolic process', 'p-value': 2.074802823938643e-10, 'matches': 221, 'identifier': 'GO:0044238', 'populationAnnotationCount': 3885}
# {'description': 'primary metabolic process', 'p-value': 2.074802823938643e-10, 'matches': 221, 'identifier': 'GO:0044238', 'populationAnnotationCount': 3885}
# {'description': 'organic substance metabolic process', 'p-value': 4.052547453335325e-10, 'matches': 226, 'identifier': 'GO:0071704', 'populationAnnotationCount': 4056}
# {'description': 'organic substance metabolic process', 'p-value': 4.052547453335325e-10, 'matches': 226, 'identifier': 'GO:0071704', 'populationAnnotationCount': 4056}
# {'description': 'organic substance metabolic process', 'p-value': 4.052547453335325e-10, 'matches': 226, 'identifier': 'GO:0071704', 'populationAnnotationCount': 4056}
# {'description': 'metabolic process', 'p-value': 4.4119745643818933e-10, 'matches': 231, 'identifier': 'GO:0008152', 'populationAnnotationCount': 4221}
# {'description': 'metabolic process', 'p-value': 4.4119745643818933e-10, 'matches': 231, 'identifier': 'GO:0008152', 'populationAnnotationCount': 4221}
# {'description': 'metabolic process', 'p-value': 4.4119745643818933e-10, 'matches': 231, 'identifier': 'GO:0008152', 'populationAnnotationCount': 4221}
# {'description': 'cellular protein metabolic process', 'p-value': 3.750474396735555e-08, 'matches': 126, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'cellular protein metabolic process', 'p-value': 3.750474396735555e-08, 'matches': 126, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'cellular protein metabolic process', 'p-value': 3.750474396735555e-08, 'matches': 126, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'ribosome biogenesis', 'p-value': 4.140751413420741e-07, 'matches': 53, 'identifier': 'GO:0042254', 'populationAnnotationCount': 475}
# {'description': 'ribosome biogenesis', 'p-value': 4.140751413420741e-07, 'matches': 53, 'identifier': 'GO:0042254', 'populationAnnotationCount': 475}
# {'description': 'ribosome biogenesis', 'p-value': 4.140751413420741e-07, 'matches': 53, 'identifier': 'GO:0042254', 'populationAnnotationCount': 475}
# {'description': 'ribonucleoprotein complex biogenesis', 'p-value': 7.576565409933483e-07, 'matches': 59, 'identifier': 'GO:0022613', 'populationAnnotationCount': 573}
# {'description': 'ribonucleoprotein complex biogenesis', 'p-value': 7.576565409933483e-07, 'matches': 59, 'identifier': 'GO:0022613', 'populationAnnotationCount': 573}
# {'description': 'ribonucleoprotein complex biogenesis', 'p-value': 7.576565409933483e-07, 'matches': 59, 'identifier': 'GO:0022613', 'populationAnnotationCount': 573}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 9.225667726148051e-07, 'matches': 131, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 9.225667726148051e-07, 'matches': 131, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 9.225667726148051e-07, 'matches': 131, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'protein metabolic process', 'p-value': 1.09602827500857e-06, 'matches': 128, 'identifier': 'GO:0019538', 'populationAnnotationCount': 1839}
# {'description': 'protein metabolic process', 'p-value': 1.09602827500857e-06, 'matches': 128, 'identifier': 'GO:0019538', 'populationAnnotationCount': 1839}
# {'description': 'protein metabolic process', 'p-value': 1.09602827500857e-06, 'matches': 128, 'identifier': 'GO:0019538', 'populationAnnotationCount': 1839}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.2702807756177674e-06, 'matches': 131, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.2702807756177674e-06, 'matches': 131, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.2702807756177674e-06, 'matches': 131, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'cytoplasmic translation', 'p-value': 1.8803192828213717e-06, 'matches': 30, 'identifier': 'GO:0002181', 'populationAnnotationCount': 187}
# {'description': 'cytoplasmic translation', 'p-value': 1.8803192828213717e-06, 'matches': 30, 'identifier': 'GO:0002181', 'populationAnnotationCount': 187}
# {'description': 'cytoplasmic translation', 'p-value': 1.8803192828213717e-06, 'matches': 30, 'identifier': 'GO:0002181', 'populationAnnotationCount': 187}
# {'description': 'ribosome assembly', 'p-value': 3.6143736100573694e-06, 'matches': 19, 'identifier': 'GO:0042255', 'populationAnnotationCount': 79}
# {'description': 'ribosome assembly', 'p-value': 3.6143736100573694e-06, 'matches': 19, 'identifier': 'GO:0042255', 'populationAnnotationCount': 79}
# {'description': 'ribosome assembly', 'p-value': 3.6143736100573694e-06, 'matches': 19, 'identifier': 'GO:0042255', 'populationAnnotationCount': 79}
# {'description': 'translational initiation', 'p-value': 4.007650397283164e-05, 'matches': 17, 'identifier': 'GO:0006413', 'populationAnnotationCount': 72}
# {'description': 'translational initiation', 'p-value': 4.007650397283164e-05, 'matches': 17, 'identifier': 'GO:0006413', 'populationAnnotationCount': 72}
# {'description': 'translational initiation', 'p-value': 4.007650397283164e-05, 'matches': 17, 'identifier': 'GO:0006413', 'populationAnnotationCount': 72}
# {'description': 'ribonucleoprotein complex subunit organization', 'p-value': 6.022318721714574e-05, 'matches': 29, 'identifier': 'GO:0071826', 'populationAnnotationCount': 203}
# {'description': 'ribonucleoprotein complex subunit organization', 'p-value': 6.022318721714574e-05, 'matches': 29, 'identifier': 'GO:0071826', 'populationAnnotationCount': 203}
# {'description': 'ribonucleoprotein complex subunit organization', 'p-value': 6.022318721714574e-05, 'matches': 29, 'identifier': 'GO:0071826', 'populationAnnotationCount': 203}
# {'description': 'cellular macromolecule metabolic process', 'p-value': 0.00010681316547600656, 'matches': 179, 'identifier': 'GO:0044260', 'populationAnnotationCount': 3118}
# {'description': 'cellular macromolecule metabolic process', 'p-value': 0.00010681316547600656, 'matches': 179, 'identifier': 'GO:0044260', 'populationAnnotationCount': 3118}
# {'description': 'cellular macromolecule metabolic process', 'p-value': 0.00010681316547600656, 'matches': 179, 'identifier': 'GO:0044260', 'populationAnnotationCount': 3118}
# {'description': 'macromolecule metabolic process', 'p-value': 0.00018051604014907501, 'matches': 183, 'identifier': 'GO:0043170', 'populationAnnotationCount': 3233}
# {'description': 'macromolecule metabolic process', 'p-value': 0.00018051604014907501, 'matches': 183, 'identifier': 'GO:0043170', 'populationAnnotationCount': 3233}
# {'description': 'macromolecule metabolic process', 'p-value': 0.00018051604014907501, 'matches': 183, 'identifier': 'GO:0043170', 'populationAnnotationCount': 3233}
# {'description': 'ribonucleoprotein complex assembly', 'p-value': 0.0002514443653018176, 'matches': 27, 'identifier': 'GO:0022618', 'populationAnnotationCount': 191}
# {'description': 'ribonucleoprotein complex assembly', 'p-value': 0.0002514443653018176, 'matches': 27, 'identifier': 'GO:0022618', 'populationAnnotationCount': 191}
# {'description': 'ribonucleoprotein complex assembly', 'p-value': 0.0002514443653018176, 'matches': 27, 'identifier': 'GO:0022618', 'populationAnnotationCount': 191}
# {'description': 'ncRNA metabolic process', 'p-value': 0.000814086762872877, 'matches': 53, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'ncRNA metabolic process', 'p-value': 0.000814086762872877, 'matches': 53, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'ncRNA metabolic process', 'p-value': 0.000814086762872877, 'matches': 53, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'ribosomal small subunit assembly', 'p-value': 0.0011239852786390225, 'matches': 10, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'ribosomal small subunit assembly', 'p-value': 0.0011239852786390225, 'matches': 10, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'ribosomal small subunit assembly', 'p-value': 0.0011239852786390225, 'matches': 10, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'ribosomal small subunit biogenesis', 'p-value': 0.0017239602691994532, 'matches': 22, 'identifier': 'GO:0042274', 'populationAnnotationCount': 147}
# {'description': 'ribosomal small subunit biogenesis', 'p-value': 0.0017239602691994532, 'matches': 22, 'identifier': 'GO:0042274', 'populationAnnotationCount': 147}
# {'description': 'ribosomal small subunit biogenesis', 'p-value': 0.0017239602691994532, 'matches': 22, 'identifier': 'GO:0042274', 'populationAnnotationCount': 147}
# {'description': 'ncRNA processing', 'p-value': 0.001728520764575832, 'matches': 45, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'ncRNA processing', 'p-value': 0.001728520764575832, 'matches': 45, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'ncRNA processing', 'p-value': 0.001728520764575832, 'matches': 45, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'RNA processing', 'p-value': 0.005292380789208374, 'matches': 55, 'identifier': 'GO:0006396', 'populationAnnotationCount': 656}
# {'description': 'RNA processing', 'p-value': 0.005292380789208374, 'matches': 55, 'identifier': 'GO:0006396', 'populationAnnotationCount': 656}
# {'description': 'RNA processing', 'p-value': 0.005292380789208374, 'matches': 55, 'identifier': 'GO:0006396', 'populationAnnotationCount': 656}
# {'description': 'rRNA metabolic process', 'p-value': 0.006615511904754437, 'matches': 37, 'identifier': 'GO:0016072', 'populationAnnotationCount': 368}
# {'description': 'rRNA metabolic process', 'p-value': 0.006615511904754437, 'matches': 37, 'identifier': 'GO:0016072', 'populationAnnotationCount': 368}
# {'description': 'rRNA metabolic process', 'p-value': 0.006615511904754437, 'matches': 37, 'identifier': 'GO:0016072', 'populationAnnotationCount': 368}
# {'description': 'organelle assembly', 'p-value': 0.007182623028798488, 'matches': 23, 'identifier': 'GO:0070925', 'populationAnnotationCount': 172}
# {'description': 'organelle assembly', 'p-value': 0.007182623028798488, 'matches': 23, 'identifier': 'GO:0070925', 'populationAnnotationCount': 172}
# {'description': 'organelle assembly', 'p-value': 0.007182623028798488, 'matches': 23, 'identifier': 'GO:0070925', 'populationAnnotationCount': 172}
# {'description': 'rRNA processing', 'p-value': 0.016097777695048415, 'matches': 35, 'identifier': 'GO:0006364', 'populationAnnotationCount': 351}
# {'description': 'cellular amino acid biosynthetic process', 'p-value': 0.02583667477673036, 'matches': 19, 'identifier': 'GO:0008652', 'populationAnnotationCount': 134}
# {'description': 'alpha-amino acid biosynthetic process', 'p-value': 0.04151699760092002, 'matches': 18, 'identifier': 'GO:1901607', 'populationAnnotationCount': 126}
# scsig_act
# The following missing genes are filtered out:
# set()
# {'description': 'oxidation-reduction process', 'p-value': 5.230705566706802e-09, 'matches': 44, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'oxidation-reduction process', 'p-value': 5.230705566706802e-09, 'matches': 44, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'oxidation-reduction process', 'p-value': 5.230705566706802e-09, 'matches': 44, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'generation of precursor metabolites and energy', 'p-value': 2.0814838057718405e-06, 'matches': 25, 'identifier': 'GO:0006091', 'populationAnnotationCount': 198}
# {'description': 'generation of precursor metabolites and energy', 'p-value': 2.0814838057718405e-06, 'matches': 25, 'identifier': 'GO:0006091', 'populationAnnotationCount': 198}
# {'description': 'generation of precursor metabolites and energy', 'p-value': 2.0814838057718405e-06, 'matches': 25, 'identifier': 'GO:0006091', 'populationAnnotationCount': 198}
# {'description': 'single-organism metabolic process', 'p-value': 4.158541141334688e-06, 'matches': 80, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'single-organism metabolic process', 'p-value': 4.158541141334688e-06, 'matches': 80, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'single-organism metabolic process', 'p-value': 4.158541141334688e-06, 'matches': 80, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'nucleotide metabolic process', 'p-value': 1.9810048434345498e-05, 'matches': 26, 'identifier': 'GO:0009117', 'populationAnnotationCount': 237}
# {'description': 'nucleotide metabolic process', 'p-value': 1.9810048434345498e-05, 'matches': 26, 'identifier': 'GO:0009117', 'populationAnnotationCount': 237}
# {'description': 'nucleotide metabolic process', 'p-value': 1.9810048434345498e-05, 'matches': 26, 'identifier': 'GO:0009117', 'populationAnnotationCount': 237}
# {'description': 'nucleoside phosphate metabolic process', 'p-value': 3.100830400286227e-05, 'matches': 26, 'identifier': 'GO:0006753', 'populationAnnotationCount': 242}
# {'description': 'nucleoside phosphate metabolic process', 'p-value': 3.100830400286227e-05, 'matches': 26, 'identifier': 'GO:0006753', 'populationAnnotationCount': 242}
# {'description': 'nucleoside phosphate metabolic process', 'p-value': 3.100830400286227e-05, 'matches': 26, 'identifier': 'GO:0006753', 'populationAnnotationCount': 242}
# {'description': 'carbohydrate metabolic process', 'p-value': 0.00014055676727744586, 'matches': 29, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'carbohydrate metabolic process', 'p-value': 0.00014055676727744586, 'matches': 29, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'carbohydrate metabolic process', 'p-value': 0.00014055676727744586, 'matches': 29, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 0.00017882491237784375, 'matches': 26, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 0.00017882491237784375, 'matches': 26, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 0.00017882491237784375, 'matches': 26, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'nucleobase-containing small molecule metabolic process', 'p-value': 0.00019340925292711381, 'matches': 26, 'identifier': 'GO:0055086', 'populationAnnotationCount': 264}
# {'description': 'nucleobase-containing small molecule metabolic process', 'p-value': 0.00019340925292711381, 'matches': 26, 'identifier': 'GO:0055086', 'populationAnnotationCount': 264}
# {'description': 'nucleobase-containing small molecule metabolic process', 'p-value': 0.00019340925292711381, 'matches': 26, 'identifier': 'GO:0055086', 'populationAnnotationCount': 264}
# {'description': 'energy derivation by oxidation of organic compounds', 'p-value': 0.00022596939804491316, 'matches': 20, 'identifier': 'GO:0015980', 'populationAnnotationCount': 163}
# {'description': 'energy derivation by oxidation of organic compounds', 'p-value': 0.00022596939804491316, 'matches': 20, 'identifier': 'GO:0015980', 'populationAnnotationCount': 163}
# {'description': 'energy derivation by oxidation of organic compounds', 'p-value': 0.00022596939804491316, 'matches': 20, 'identifier': 'GO:0015980', 'populationAnnotationCount': 163}
# {'description': 'tricarboxylic acid cycle', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006099', 'populationAnnotationCount': 30}
# {'description': 'tricarboxylic acid cycle', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006099', 'populationAnnotationCount': 30}
# {'description': 'tricarboxylic acid cycle', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006099', 'populationAnnotationCount': 30}
# {'description': 'citrate metabolic process', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006101', 'populationAnnotationCount': 30}
# {'description': 'citrate metabolic process', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006101', 'populationAnnotationCount': 30}
# {'description': 'citrate metabolic process', 'p-value': 0.000587925144891532, 'matches': 9, 'identifier': 'GO:0006101', 'populationAnnotationCount': 30}
# {'description': 'ribose phosphate metabolic process', 'p-value': 0.0007514309939815119, 'matches': 20, 'identifier': 'GO:0019693', 'populationAnnotationCount': 175}
# {'description': 'ribose phosphate metabolic process', 'p-value': 0.0007514309939815119, 'matches': 20, 'identifier': 'GO:0019693', 'populationAnnotationCount': 175}
# {'description': 'ribose phosphate metabolic process', 'p-value': 0.0007514309939815119, 'matches': 20, 'identifier': 'GO:0019693', 'populationAnnotationCount': 175}
# {'description': 'oxidoreduction coenzyme metabolic process', 'p-value': 0.0007525876857489592, 'matches': 15, 'identifier': 'GO:0006733', 'populationAnnotationCount': 99}
# {'description': 'oxidoreduction coenzyme metabolic process', 'p-value': 0.0007525876857489592, 'matches': 15, 'identifier': 'GO:0006733', 'populationAnnotationCount': 99}
# {'description': 'oxidoreduction coenzyme metabolic process', 'p-value': 0.0007525876857489592, 'matches': 15, 'identifier': 'GO:0006733', 'populationAnnotationCount': 99}
# {'description': 'tricarboxylic acid metabolic process', 'p-value': 0.0008070962668641697, 'matches': 9, 'identifier': 'GO:0072350', 'populationAnnotationCount': 31}
# {'description': 'tricarboxylic acid metabolic process', 'p-value': 0.0008070962668641697, 'matches': 9, 'identifier': 'GO:0072350', 'populationAnnotationCount': 31}
# {'description': 'tricarboxylic acid metabolic process', 'p-value': 0.0008070962668641697, 'matches': 9, 'identifier': 'GO:0072350', 'populationAnnotationCount': 31}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 0.0008161208568434072, 'matches': 22, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 0.0008161208568434072, 'matches': 22, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 0.0008161208568434072, 'matches': 22, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'purine ribonucleoside triphosphate metabolic process', 'p-value': 0.0014662432779022508, 'matches': 15, 'identifier': 'GO:0009205', 'populationAnnotationCount': 104}
# {'description': 'purine ribonucleoside triphosphate metabolic process', 'p-value': 0.0014662432779022508, 'matches': 15, 'identifier': 'GO:0009205', 'populationAnnotationCount': 104}
# {'description': 'purine ribonucleoside triphosphate metabolic process', 'p-value': 0.0014662432779022508, 'matches': 15, 'identifier': 'GO:0009205', 'populationAnnotationCount': 104}
# {'description': 'purine nucleoside triphosphate metabolic process', 'p-value': 0.0018927700394925095, 'matches': 15, 'identifier': 'GO:0009144', 'populationAnnotationCount': 106}
# {'description': 'purine nucleoside triphosphate metabolic process', 'p-value': 0.0018927700394925095, 'matches': 15, 'identifier': 'GO:0009144', 'populationAnnotationCount': 106}
# {'description': 'purine nucleoside triphosphate metabolic process', 'p-value': 0.0018927700394925095, 'matches': 15, 'identifier': 'GO:0009144', 'populationAnnotationCount': 106}
# {'description': 'mitochondrial electron transport, succinate to ubiquinone', 'p-value': 0.002182632458293142, 'matches': 5, 'identifier': 'GO:0006121', 'populationAnnotationCount': 7}
# {'description': 'mitochondrial electron transport, succinate to ubiquinone', 'p-value': 0.002182632458293142, 'matches': 5, 'identifier': 'GO:0006121', 'populationAnnotationCount': 7}
# {'description': 'mitochondrial electron transport, succinate to ubiquinone', 'p-value': 0.002182632458293142, 'matches': 5, 'identifier': 'GO:0006121', 'populationAnnotationCount': 7}
# {'description': 'ribonucleoside triphosphate metabolic process', 'p-value': 0.002427902962982402, 'matches': 15, 'identifier': 'GO:0009199', 'populationAnnotationCount': 108}
# {'description': 'ribonucleoside triphosphate metabolic process', 'p-value': 0.002427902962982402, 'matches': 15, 'identifier': 'GO:0009199', 'populationAnnotationCount': 108}
# {'description': 'ribonucleoside triphosphate metabolic process', 'p-value': 0.002427902962982402, 'matches': 15, 'identifier': 'GO:0009199', 'populationAnnotationCount': 108}
# {'description': 'pyridine nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0019362', 'populationAnnotationCount': 84}
# {'description': 'pyridine nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0019362', 'populationAnnotationCount': 84}
# {'description': 'pyridine nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0019362', 'populationAnnotationCount': 84}
# {'description': 'nicotinamide nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0046496', 'populationAnnotationCount': 84}
# {'description': 'nicotinamide nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0046496', 'populationAnnotationCount': 84}
# {'description': 'nicotinamide nucleotide metabolic process', 'p-value': 0.004133676570612348, 'matches': 13, 'identifier': 'GO:0046496', 'populationAnnotationCount': 84}
# {'description': 'ATP metabolic process', 'p-value': 0.0047709511042181635, 'matches': 14, 'identifier': 'GO:0046034', 'populationAnnotationCount': 99}
# {'description': 'ATP metabolic process', 'p-value': 0.0047709511042181635, 'matches': 14, 'identifier': 'GO:0046034', 'populationAnnotationCount': 99}
# {'description': 'ATP metabolic process', 'p-value': 0.0047709511042181635, 'matches': 14, 'identifier': 'GO:0046034', 'populationAnnotationCount': 99}
# {'description': 'carbohydrate derivative metabolic process', 'p-value': 0.00635697732837156, 'matches': 29, 'identifier': 'GO:1901135', 'populationAnnotationCount': 377}
# {'description': 'carbohydrate derivative metabolic process', 'p-value': 0.00635697732837156, 'matches': 29, 'identifier': 'GO:1901135', 'populationAnnotationCount': 377}
# {'description': 'carbohydrate derivative metabolic process', 'p-value': 0.00635697732837156, 'matches': 29, 'identifier': 'GO:1901135', 'populationAnnotationCount': 377}
# {'description': 'nucleoside triphosphate metabolic process', 'p-value': 0.006946077306957916, 'matches': 15, 'identifier': 'GO:0009141', 'populationAnnotationCount': 117}
# {'description': 'nucleoside triphosphate metabolic process', 'p-value': 0.006946077306957916, 'matches': 15, 'identifier': 'GO:0009141', 'populationAnnotationCount': 117}
# {'description': 'nucleoside triphosphate metabolic process', 'p-value': 0.006946077306957916, 'matches': 15, 'identifier': 'GO:0009141', 'populationAnnotationCount': 117}
# {'description': 'ribonucleoside metabolic process', 'p-value': 0.0070809531234694465, 'matches': 17, 'identifier': 'GO:0009119', 'populationAnnotationCount': 149}
# {'description': 'ribonucleoside metabolic process', 'p-value': 0.0070809531234694465, 'matches': 17, 'identifier': 'GO:0009119', 'populationAnnotationCount': 149}
# {'description': 'ribonucleoside metabolic process', 'p-value': 0.0070809531234694465, 'matches': 17, 'identifier': 'GO:0009119', 'populationAnnotationCount': 149}
# {'description': 'purine ribonucleoside metabolic process', 'p-value': 0.007233573926706066, 'matches': 16, 'identifier': 'GO:0046128', 'populationAnnotationCount': 133}
# {'description': 'purine ribonucleoside metabolic process', 'p-value': 0.007233573926706066, 'matches': 16, 'identifier': 'GO:0046128', 'populationAnnotationCount': 133}
# {'description': 'purine ribonucleoside metabolic process', 'p-value': 0.007233573926706066, 'matches': 16, 'identifier': 'GO:0046128', 'populationAnnotationCount': 133}
# {'description': 'purine nucleoside metabolic process', 'p-value': 0.008005235820671449, 'matches': 16, 'identifier': 'GO:0042278', 'populationAnnotationCount': 134}
# {'description': 'purine nucleoside metabolic process', 'p-value': 0.008005235820671449, 'matches': 16, 'identifier': 'GO:0042278', 'populationAnnotationCount': 134}
# {'description': 'purine nucleoside metabolic process', 'p-value': 0.008005235820671449, 'matches': 16, 'identifier': 'GO:0042278', 'populationAnnotationCount': 134}
# {'description': 'ribonucleotide metabolic process', 'p-value': 0.01233647998506758, 'matches': 17, 'identifier': 'GO:0009259', 'populationAnnotationCount': 155}
# {'description': 'organophosphate metabolic process', 'p-value': 0.012742013862656783, 'matches': 31, 'identifier': 'GO:0019637', 'populationAnnotationCount': 434}
# {'description': 'ribonucleoside monophosphate metabolic process', 'p-value': 0.014415151827929214, 'matches': 16, 'identifier': 'GO:0009161', 'populationAnnotationCount': 140}
# {'description': 'purine nucleoside monophosphate metabolic process', 'p-value': 0.014648167276291597, 'matches': 15, 'identifier': 'GO:0009126', 'populationAnnotationCount': 124}
# {'description': 'purine ribonucleoside monophosphate metabolic process', 'p-value': 0.014648167276291597, 'matches': 15, 'identifier': 'GO:0009167', 'populationAnnotationCount': 124}
# {'description': 'purine ribonucleotide metabolic process', 'p-value': 0.017400200877775794, 'matches': 16, 'identifier': 'GO:0009150', 'populationAnnotationCount': 142}
# {'description': 'nucleoside monophosphate metabolic process', 'p-value': 0.019093319798356993, 'matches': 16, 'identifier': 'GO:0009123', 'populationAnnotationCount': 143}
# {'description': 'nucleoside metabolic process', 'p-value': 0.019153316568220294, 'matches': 17, 'identifier': 'GO:0009116', 'populationAnnotationCount': 160}
# {'description': 'pyridine-containing compound metabolic process', 'p-value': 0.01955189783587873, 'matches': 13, 'identifier': 'GO:0072524', 'populationAnnotationCount': 96}
# {'description': 'purine nucleotide metabolic process', 'p-value': 0.02509597993059181, 'matches': 16, 'identifier': 'GO:0006163', 'populationAnnotationCount': 146}
# {'description': 'glycosyl compound metabolic process', 'p-value': 0.029214406704572014, 'matches': 17, 'identifier': 'GO:1901657', 'populationAnnotationCount': 165}
# {'description': 'cellular response to oxidative stress', 'p-value': 0.029571409847286127, 'matches': 14, 'identifier': 'GO:0034599', 'populationAnnotationCount': 115}
# {'description': 'cellular oxidant detoxification', 'p-value': 0.04618529750419306, 'matches': 8, 'identifier': 'GO:0098869', 'populationAnnotationCount': 37}
# scsig_rep
# The following missing genes are filtered out:
# set()
# {'description': 'ncRNA metabolic process', 'p-value': 6.415710539122057e-08, 'matches': 39, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'ncRNA metabolic process', 'p-value': 6.415710539122057e-08, 'matches': 39, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'ncRNA metabolic process', 'p-value': 6.415710539122057e-08, 'matches': 39, 'identifier': 'GO:0034660', 'populationAnnotationCount': 587}
# {'description': 'tRNA metabolic process', 'p-value': 8.590568531953101e-08, 'matches': 23, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'tRNA metabolic process', 'p-value': 8.590568531953101e-08, 'matches': 23, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'tRNA metabolic process', 'p-value': 8.590568531953101e-08, 'matches': 23, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'ncRNA processing', 'p-value': 0.0011983336102535029, 'matches': 28, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'ncRNA processing', 'p-value': 0.0011983336102535029, 'matches': 28, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'ncRNA processing', 'p-value': 0.0011983336102535029, 'matches': 28, 'identifier': 'GO:0034470', 'populationAnnotationCount': 471}
# {'description': 'cleavage involved in rRNA processing', 'p-value': 0.003758308161084862, 'matches': 11, 'identifier': 'GO:0000469', 'populationAnnotationCount': 81}
# {'description': 'cleavage involved in rRNA processing', 'p-value': 0.003758308161084862, 'matches': 11, 'identifier': 'GO:0000469', 'populationAnnotationCount': 81}
# {'description': 'cleavage involved in rRNA processing', 'p-value': 0.003758308161084862, 'matches': 11, 'identifier': 'GO:0000469', 'populationAnnotationCount': 81}
# {'description': 'maturation of 5.8S rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)', 'p-value': 0.008773176076478206, 'matches': 11, 'identifier': 'GO:0000466', 'populationAnnotationCount': 88}
# {'description': 'maturation of 5.8S rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)', 'p-value': 0.008773176076478206, 'matches': 11, 'identifier': 'GO:0000466', 'populationAnnotationCount': 88}
# {'description': 'maturation of 5.8S rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)', 'p-value': 0.008773176076478206, 'matches': 11, 'identifier': 'GO:0000466', 'populationAnnotationCount': 88}
# {'description': 'maturation of 5.8S rRNA', 'p-value': 0.009834463676021043, 'matches': 11, 'identifier': 'GO:0000460', 'populationAnnotationCount': 89}
# {'description': 'maturation of 5.8S rRNA', 'p-value': 0.009834463676021043, 'matches': 11, 'identifier': 'GO:0000460', 'populationAnnotationCount': 89}
# {'description': 'maturation of 5.8S rRNA', 'p-value': 0.009834463676021043, 'matches': 11, 'identifier': 'GO:0000460', 'populationAnnotationCount': 89}
# {'description': 'ribosome biogenesis', 'p-value': 0.017269939767013357, 'matches': 26, 'identifier': 'GO:0042254', 'populationAnnotationCount': 475}
# {'description': 'glutamine family amino acid metabolic process', 'p-value': 0.026393096582410132, 'matches': 9, 'identifier': 'GO:0009064', 'populationAnnotationCount': 63}
# {'description': 'cellular amino acid metabolic process', 'p-value': 0.02691490222273958, 'matches': 18, 'identifier': 'GO:0006520', 'populationAnnotationCount': 258}
# klscsig_act
# The following missing genes are filtered out:
# set()
# {'description': 'single-organism metabolic process', 'p-value': 2.021335666028154e-08, 'matches': 54, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'single-organism metabolic process', 'p-value': 2.021335666028154e-08, 'matches': 54, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'single-organism metabolic process', 'p-value': 2.021335666028154e-08, 'matches': 54, 'identifier': 'GO:0044710', 'populationAnnotationCount': 1485}
# {'description': 'oxidation-reduction process', 'p-value': 2.3980721250375784e-08, 'matches': 30, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'oxidation-reduction process', 'p-value': 2.3980721250375784e-08, 'matches': 30, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'oxidation-reduction process', 'p-value': 2.3980721250375784e-08, 'matches': 30, 'identifier': 'GO:0055114', 'populationAnnotationCount': 467}
# {'description': 'trehalose metabolic process', 'p-value': 6.875799618980739e-07, 'matches': 7, 'identifier': 'GO:0005991', 'populationAnnotationCount': 12}
# {'description': 'trehalose metabolic process', 'p-value': 6.875799618980739e-07, 'matches': 7, 'identifier': 'GO:0005991', 'populationAnnotationCount': 12}
# {'description': 'trehalose metabolic process', 'p-value': 6.875799618980739e-07, 'matches': 7, 'identifier': 'GO:0005991', 'populationAnnotationCount': 12}
# {'description': 'carbohydrate metabolic process', 'p-value': 1.2137466631579154e-06, 'matches': 23, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'carbohydrate metabolic process', 'p-value': 1.2137466631579154e-06, 'matches': 23, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'carbohydrate metabolic process', 'p-value': 1.2137466631579154e-06, 'matches': 23, 'identifier': 'GO:0005975', 'populationAnnotationCount': 316}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 1.5071557436324058e-06, 'matches': 19, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 1.5071557436324058e-06, 'matches': 19, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'cellular carbohydrate metabolic process', 'p-value': 1.5071557436324058e-06, 'matches': 19, 'identifier': 'GO:0044262', 'populationAnnotationCount': 210}
# {'description': 'trehalose metabolism in response to stress', 'p-value': 4.320246296185489e-06, 'matches': 5, 'identifier': 'GO:0070413', 'populationAnnotationCount': 5}
# {'description': 'trehalose metabolism in response to stress', 'p-value': 4.320246296185489e-06, 'matches': 5, 'identifier': 'GO:0070413', 'populationAnnotationCount': 5}
# {'description': 'trehalose metabolism in response to stress', 'p-value': 4.320246296185489e-06, 'matches': 5, 'identifier': 'GO:0070413', 'populationAnnotationCount': 5}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 1.0646718455898953e-05, 'matches': 20, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 1.0646718455898953e-05, 'matches': 20, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'single-organism carbohydrate metabolic process', 'p-value': 1.0646718455898953e-05, 'matches': 20, 'identifier': 'GO:0044723', 'populationAnnotationCount': 263}
# {'description': 'trehalose biosynthetic process', 'p-value': 8.848064606838846e-05, 'matches': 5, 'identifier': 'GO:0005992', 'populationAnnotationCount': 7}
# ...
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.6146961030615892e-15, 'matches': 157, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.6146961030615892e-15, 'matches': 157, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'organonitrogen compound metabolic process', 'p-value': 1.6146961030615892e-15, 'matches': 157, 'identifier': 'GO:1901564', 'populationAnnotationCount': 1405}
# {'description': 'RNA phosphodiester bond hydrolysis, endonucleolytic', 'p-value': 1.1046329136265063e-14, 'matches': 41, 'identifier': 'GO:0090502', 'populationAnnotationCount': 142}
# {'description': 'RNA phosphodiester bond hydrolysis, endonucleolytic', 'p-value': 1.1046329136265063e-14, 'matches': 41, 'identifier': 'GO:0090502', 'populationAnnotationCount': 142}
# {'description': 'RNA phosphodiester bond hydrolysis, endonucleolytic', 'p-value': 1.1046329136265063e-14, 'matches': 41, 'identifier': 'GO:0090502', 'populationAnnotationCount': 142}
# {'description': 'RNA phosphodiester bond hydrolysis', 'p-value': 9.372585996885215e-14, 'matches': 47, 'identifier': 'GO:0090501', 'populationAnnotationCount': 195}
# {'description': 'RNA phosphodiester bond hydrolysis', 'p-value': 9.372585996885215e-14, 'matches': 47, 'identifier': 'GO:0090501', 'populationAnnotationCount': 195}
# {'description': 'RNA phosphodiester bond hydrolysis', 'p-value': 9.372585996885215e-14, 'matches': 47, 'identifier': 'GO:0090501', 'populationAnnotationCount': 195}
# {'description': 'ribonucleoprotein complex export from nucleus', 'p-value': 1.7926864221285404e-13, 'matches': 38, 'identifier': 'GO:0071426', 'populationAnnotationCount': 131}
# {'description': 'ribonucleoprotein complex export from nucleus', 'p-value': 1.7926864221285404e-13, 'matches': 38, 'identifier': 'GO:0071426', 'populationAnnotationCount': 131}
# {'description': 'ribonucleoprotein complex export from nucleus', 'p-value': 1.7926864221285404e-13, 'matches': 38, 'identifier': 'GO:0071426', 'populationAnnotationCount': 131}
# {'description': 'ribonucleoprotein complex localization', 'p-value': 3.1635368364681284e-13, 'matches': 38, 'identifier': 'GO:0071166', 'populationAnnotationCount': 133}
# {'description': 'ribonucleoprotein complex localization', 'p-value': 3.1635368364681284e-13, 'matches': 38, 'identifier': 'GO:0071166', 'populationAnnotationCount': 133}
# {'description': 'ribonucleoprotein complex localization', 'p-value': 3.1635368364681284e-13, 'matches': 38, 'identifier': 'GO:0071166', 'populationAnnotationCount': 133}
# {'description': 'nuclear export', 'p-value': 1.6215008178279745e-12, 'matches': 38, 'identifier': 'GO:0051168', 'populationAnnotationCount': 139}
# {'description': 'nuclear export', 'p-value': 1.6215008178279745e-12, 'matches': 38, 'identifier': 'GO:0051168', 'populationAnnotationCount': 139}
# {'description': 'nuclear export', 'p-value': 1.6215008178279745e-12, 'matches': 38, 'identifier': 'GO:0051168', 'populationAnnotationCount': 139}
# {'description': 'nucleocytoplasmic transport', 'p-value': 1.2816314295274604e-11, 'matches': 43, 'identifier': 'GO:0006913', 'populationAnnotationCount': 186}
# {'description': 'nucleocytoplasmic transport', 'p-value': 1.2816314295274604e-11, 'matches': 43, 'identifier': 'GO:0006913', 'populationAnnotationCount': 186}
# {'description': 'nucleocytoplasmic transport', 'p-value': 1.2816314295274604e-11, 'matches': 43, 'identifier': 'GO:0006913', 'populationAnnotationCount': 186}
# {'description': 'nuclear transport', 'p-value': 1.5771428123620305e-11, 'matches': 43, 'identifier': 'GO:0051169', 'populationAnnotationCount': 187}
# {'description': 'nuclear transport', 'p-value': 1.5771428123620305e-11, 'matches': 43, 'identifier': 'GO:0051169', 'populationAnnotationCount': 187}
# {'description': 'nuclear transport', 'p-value': 1.5771428123620305e-11, 'matches': 43, 'identifier': 'GO:0051169', 'populationAnnotationCount': 187}
# {'description': 'ribosomal small subunit assembly', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'ribosomal small subunit assembly', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'ribosomal small subunit assembly', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0000028', 'populationAnnotationCount': 29}
# {'description': 'regulation of translational fidelity', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0006450', 'populationAnnotationCount': 29}
# {'description': 'regulation of translational fidelity', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0006450', 'populationAnnotationCount': 29}
# {'description': 'regulation of translational fidelity', 'p-value': 1.4017533362469904e-10, 'matches': 17, 'identifier': 'GO:0006450', 'populationAnnotationCount': 29}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 2.2964962635219464e-10, 'matches': 176, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 2.2964962635219464e-10, 'matches': 176, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'cellular nitrogen compound biosynthetic process', 'p-value': 2.2964962635219464e-10, 'matches': 176, 'identifier': 'GO:0044271', 'populationAnnotationCount': 1865}
# {'description': 'regulation of translational elongation', 'p-value': 3.838595686232152e-10, 'matches': 19, 'identifier': 'GO:0006448', 'populationAnnotationCount': 39}
# {'description': 'regulation of translational elongation', 'p-value': 3.838595686232152e-10, 'matches': 19, 'identifier': 'GO:0006448', 'populationAnnotationCount': 39}
# {'description': 'regulation of translational elongation', 'p-value': 3.838595686232152e-10, 'matches': 19, 'identifier': 'GO:0006448', 'populationAnnotationCount': 39}
# {'description': 'ribosomal subunit export from nucleus', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0000054', 'populationAnnotationCount': 48}
# {'description': 'ribosomal subunit export from nucleus', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0000054', 'populationAnnotationCount': 48}
# {'description': 'ribosomal subunit export from nucleus', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0000054', 'populationAnnotationCount': 48}
# {'description': 'establishment of ribosome localization', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0033753', 'populationAnnotationCount': 48}
# {'description': 'establishment of ribosome localization', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0033753', 'populationAnnotationCount': 48}
# {'description': 'establishment of ribosome localization', 'p-value': 3.3827175235645332e-09, 'matches': 20, 'identifier': 'GO:0033753', 'populationAnnotationCount': 48}
# {'description': 'nucleic acid phosphodiester bond hydrolysis', 'p-value': 3.7004468925030307e-09, 'matches': 50, 'identifier': 'GO:0090305', 'populationAnnotationCount': 281}
# {'description': 'nucleic acid phosphodiester bond hydrolysis', 'p-value': 3.7004468925030307e-09, 'matches': 50, 'identifier': 'GO:0090305', 'populationAnnotationCount': 281}
# {'description': 'nucleic acid phosphodiester bond hydrolysis', 'p-value': 3.7004468925030307e-09, 'matches': 50, 'identifier': 'GO:0090305', 'populationAnnotationCount': 281}
# {'description': 'ribosome localization', 'p-value': 5.406345289764284e-09, 'matches': 20, 'identifier': 'GO:0033750', 'populationAnnotationCount': 49}
# {'description': 'ribosome localization', 'p-value': 5.406345289764284e-09, 'matches': 20, 'identifier': 'GO:0033750', 'populationAnnotationCount': 49}
# {'description': 'ribosome localization', 'p-value': 5.406345289764284e-09, 'matches': 20, 'identifier': 'GO:0033750', 'populationAnnotationCount': 49}
# {'description': 'rRNA export from nucleus', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0006407', 'populationAnnotationCount': 18}
# {'description': 'rRNA export from nucleus', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0006407', 'populationAnnotationCount': 18}
# {'description': 'rRNA export from nucleus', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0006407', 'populationAnnotationCount': 18}
# {'description': 'rRNA transport', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0051029', 'populationAnnotationCount': 18}
# {'description': 'rRNA transport', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0051029', 'populationAnnotationCount': 18}
# {'description': 'rRNA transport', 'p-value': 1.1416441095675305e-07, 'matches': 12, 'identifier': 'GO:0051029', 'populationAnnotationCount': 18}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 7.019963923000122e-07, 'matches': 168, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 7.019963923000122e-07, 'matches': 168, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'cellular macromolecule biosynthetic process', 'p-value': 7.019963923000122e-07, 'matches': 168, 'identifier': 'GO:0034645', 'populationAnnotationCount': 1897}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.0231722143435962e-06, 'matches': 168, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.0231722143435962e-06, 'matches': 168, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'macromolecule biosynthetic process', 'p-value': 1.0231722143435962e-06, 'matches': 168, 'identifier': 'GO:0009059', 'populationAnnotationCount': 1905}
# {'description': 'RNA secondary structure unwinding', 'p-value': 4.573975841860619e-06, 'matches': 13, 'identifier': 'GO:0010501', 'populationAnnotationCount': 27}
# {'description': 'RNA secondary structure unwinding', 'p-value': 4.573975841860619e-06, 'matches': 13, 'identifier': 'GO:0010501', 'populationAnnotationCount': 27}
# {'description': 'RNA secondary structure unwinding', 'p-value': 4.573975841860619e-06, 'matches': 13, 'identifier': 'GO:0010501', 'populationAnnotationCount': 27}
# {'description': 'assembly of large subunit precursor of preribosome', 'p-value': 3.060857629717604e-05, 'matches': 8, 'identifier': 'GO:1902626', 'populationAnnotationCount': 10}
# {'description': 'assembly of large subunit precursor of preribosome', 'p-value': 3.060857629717604e-05, 'matches': 8, 'identifier': 'GO:1902626', 'populationAnnotationCount': 10}
# {'description': 'assembly of large subunit precursor of preribosome', 'p-value': 3.060857629717604e-05, 'matches': 8, 'identifier': 'GO:1902626', 'populationAnnotationCount': 10}
# {'description': 'tRNA metabolic process', 'p-value': 3.839845814555503e-05, 'matches': 35, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'tRNA metabolic process', 'p-value': 3.839845814555503e-05, 'matches': 35, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'tRNA metabolic process', 'p-value': 3.839845814555503e-05, 'matches': 35, 'identifier': 'GO:0006399', 'populationAnnotationCount': 204}
# {'description': 'cellular protein metabolic process', 'p-value': 0.0014520196051751063, 'matches': 145, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'cellular protein metabolic process', 'p-value': 0.0014520196051751063, 'matches': 145, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'cellular protein metabolic process', 'p-value': 0.0014520196051751063, 'matches': 145, 'identifier': 'GO:0044267', 'populationAnnotationCount': 1719}
# {'description': 'cellular macromolecular complex assembly', 'p-value': 0.003122579225327374, 'matches': 62, 'identifier': 'GO:0034622', 'populationAnnotationCount': 560}
# {'description': 'cellular macromolecular complex assembly', 'p-value': 0.003122579225327374, 'matches': 62, 'identifier': 'GO:0034622', 'populationAnnotationCount': 560}
# {'description': 'cellular macromolecular complex assembly', 'p-value': 0.003122579225327374, 'matches': 62, 'identifier': 'GO:0034622', 'populationAnnotationCount': 560}
# {'description': 'nucleobase-containing compound transport', 'p-value': 0.0040138088332279396, 'matches': 30, 'identifier': 'GO:0015931', 'populationAnnotationCount': 192}
# {'description': 'nucleobase-containing compound transport', 'p-value': 0.0040138088332279396, 'matches': 30, 'identifier': 'GO:0015931', 'populationAnnotationCount': 192}
# {'description': 'nucleobase-containing compound transport', 'p-value': 0.0040138088332279396, 'matches': 30, 'identifier': 'GO:0015931', 'populationAnnotationCount': 192}
# {'description': 'ncRNA transcription', 'p-value': 0.005737576472936224, 'matches': 15, 'identifier': 'GO:0098781', 'populationAnnotationCount': 59}
# {'description': 'ncRNA transcription', 'p-value': 0.005737576472936224, 'matches': 15, 'identifier': 'GO:0098781', 'populationAnnotationCount': 59}
# {'description': 'ncRNA transcription', 'p-value': 0.005737576472936224, 'matches': 15, 'identifier': 'GO:0098781', 'populationAnnotationCount': 59}
# {'description': 'cellular biosynthetic process', 'p-value': 0.006669154180539723, 'matches': 187, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'cellular biosynthetic process', 'p-value': 0.006669154180539723, 'matches': 187, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'cellular biosynthetic process', 'p-value': 0.006669154180539723, 'matches': 187, 'identifier': 'GO:0044249', 'populationAnnotationCount': 2431}
# {'description': 'transcription from RNA polymerase I promoter', 'p-value': 0.0077382234271341725, 'matches': 16, 'identifier': 'GO:0006360', 'populationAnnotationCount': 68}
# {'description': 'transcription from RNA polymerase I promoter', 'p-value': 0.0077382234271341725, 'matches': 16, 'identifier': 'GO:0006360', 'populationAnnotationCount': 68}
# {'description': 'transcription from RNA polymerase I promoter', 'p-value': 0.0077382234271341725, 'matches': 16, 'identifier': 'GO:0006360', 'populationAnnotationCount': 68}
# {'description': 'organic substance biosynthetic process', 'p-value': 0.012047647002194887, 'matches': 187, 'identifier': 'GO:1901576', 'populationAnnotationCount': 2449}
# {'description': 'biosynthetic process', 'p-value': 0.012408891657273487, 'matches': 189, 'identifier': 'GO:0009058', 'populationAnnotationCount': 2483}
# {'description': 'ribosomal large subunit export from nucleus', 'p-value': 0.01268136272859071, 'matches': 10, 'identifier': 'GO:0000055', 'populationAnnotationCount': 28}
# {'description': 'snRNA pseudouridine synthesis', 'p-value': 0.015915834537195857, 'matches': 6, 'identifier': 'GO:0031120', 'populationAnnotationCount': 9}
# {'description': 'snRNA modification', 'p-value': 0.015915834537195857, 'matches': 6, 'identifier': 'GO:0040031', 'populationAnnotationCount': 9}
# {'description': 'macromolecular complex assembly', 'p-value': 0.031190256949736643, 'matches': 63, 'identifier': 'GO:0065003', 'populationAnnotationCount': 612}
# {'description': 'tRNA transcription from RNA polymerase III promoter', 'p-value': 0.031842550772909164, 'matches': 8, 'identifier': 'GO:0042797', 'populationAnnotationCount': 19}
# {'description': 'RNA export from nucleus', 'p-value': 0.03465344038767785, 'matches': 19, 'identifier': 'GO:0006405', 'populationAnnotationCount': 102}
# {'description': 'protein metabolic process', 'p-value': 0.03624084467492526, 'matches': 147, 'identifier': 'GO:0019538', 'populationAnnotationCount': 1839}
# {'description': 'RNA localization', 'p-value': 0.04963893130926979, 'matches': 24, 'identifier': 'GO:0006403', 'populationAnnotationCount': 153}

# %%
missing_genes = ['Scer_YGOB_YDR134C', 'Scer_RDN18-1', 
                 'Scer_YGOB_SDC25', 'Scer_RDN25-1', 
                 'Scer_RDN58-1', 'Scer_YGOB_Anc_7.495', 
                 'Scer_YGOB_ADL119W', 'Scer_RDN5-1']


klsig_act_genes = list(kl_sc_PKA_data_klsig_scunsig[kl_sc_PKA_data_klsig_scunsig['PKA(AS)+1NMPP1_KL']>0]['sc_genename'])
klsig_act_genes.append('YJL208C')
print(len(set(klsig_act_genes)))
print(len(set(missing_genes)))
set(klsig_act_genes) & set(missing_genes)
# Out:
# 233
# 8
# {'Scer_YGOB_SDC25'}

# %%
selection = [1,4,6,10]
gene_subset = [query_list[jj].secondaryIdentifier for jj in selection]
gene_subset
# Out:
# ['YBR196C', 'YFL007W', 'YBL049W', 'YDR222W']

# %%
list2 = list(query)

# %%
len(list2)
# Out:
# 4

# %%
for row in query_list:
    print(row["primaryIdentifier"], row["secondaryIdentifier"], row["organism.shortName"], \
        row["symbol"], row["name"], row["id"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-181-b91906e2eba9> in <module>()
#       1 for row in query_list:
# ----> 2     print(row["primaryIdentifier"], row["secondaryIdentifier"], row["organism.shortName"],         row["symbol"], row["name"], row["id"])
#
# /usr/local/lib/python3.5/dist-packages/intermine-1.9.9-py3.5.egg/intermine/results.py in __getitem__(self, key)
#     233             return self.data[key]
#     234         else:
# --> 235             index = self._get_index_for(key)
#     236             return self.data[index]
#     237
#
# /usr/local/lib/python3.5/dist-packages/intermine-1.9.9-py3.5.egg/intermine/results.py in _get_index_for(self, key)
#     213                 self.index_map[headless_view] = i
#     214
# --> 215         return self.index_map[key]
#     216
#     217     def __str__(self):
#
# KeyError: 'primaryIdentifier'

# %%
##To see a list of widgets that are available
service.widgets
# Out:
# {'go_enrichment_for_gene': {'description': 'GO terms enriched for items in this list.',
#   'enrich': 'goAnnotation.ontologyTerm.parents.name',
#   'enrichIdentifier': 'goAnnotation.ontologyTerm.parents.identifier',
#   'filters': 'biological_process,cellular_component,molecular_function',
#   'name': 'go_enrichment_for_gene',
#   'startClass': 'Gene',
#   'startClassDisplay': 'secondaryIdentifier',
#   'targets': ['Gene'],
#   'title': 'Gene Ontology Enrichment',
#   'widgetType': 'enrichment'},
#  'interactions': {'description': 'Genes (from the list or not) that interact with genes in this list.  Counts may include the same interaction more than once if observed in multiple experiments.',
#   'filters': None,
#   'name': 'interactions',
#   'startClass': None,
#   'targets': ['Gene'],
#   'title': 'Interactions',
#   'widgetType': 'table'},
#  'orthologues': {'description': 'Shows the number of Genes in list with orthologue not the number of orthologues.',
#   'filters': None,
#   'name': 'orthologues',
#   'startClass': None,
#   'targets': ['Gene'],
#   'title': 'Orthologues',
#   'widgetType': 'table'},
#  'pathway_enrichment': {'description': 'Pathways enriched for genes in this list - data from KEGG and Reactome',
#   'enrich': 'pathways.name',
#   'enrichIdentifier': 'pathways.identifier',
#   'filters': 'All,KEGG pathways data set,Reactome data set',
#   'name': 'pathway_enrichment',
#   'startClass': 'Gene',
#   'startClassDisplay': 'secondaryIdentifier',
#   'targets': ['Gene'],
#   'title': 'Pathway Enrichment',
#   'widgetType': 'enrichment'},
#  'publication_enrichment': {'description': 'Publications enriched for genes in this list.',
#   'enrich': 'publications.title',
#   'enrichIdentifier': 'publications.pubMedId',
#   'filters': None,
#   'name': 'publication_enrichment',
#   'startClass': 'Gene',
#   'startClassDisplay': 'secondaryIdentifier',
#   'targets': ['Gene'],
#   'title': 'Publication Enrichment',
#   'widgetType': 'enrichment'}}

# %%
# Out:
# intermine.results.EnrichmentLine

# %%
results = new_list.calculate_enrichment('go_enrichment_for_gene')

# %%
results_parser = results.parser

# %%
res = list(results)

# %%
item = res[0]

item['matches']
# Out:
# 16

# %%
print(res[1])
# Out:
# {'description': 'cellular lipid catabolic process', 'p-value': 2.0996195815425373e-06, 'matches': 14, 'identifier': 'GO:0044242', 'populationAnnotationCount': 46}

# %%
#Get genes from a go term.  

from intermine.webservice import Service
service = Service("http://yeastmine.yeastgenome.org:443/yeastmine/service")
query = service.new_query("Gene")
query.add_view(
    "primaryIdentifier", "secondaryIdentifier", "symbol", "featureType",
    "goAnnotation.qualifier", "goAnnotation.ontologyTerm.identifier",
    "goAnnotation.ontologyTerm.name", "goAnnotation.ontologyTerm.namespace",
    "goAnnotation.evidence.code.code", "goAnnotation.evidence.code.withText",
    "goAnnotation.evidence.code.annotType",
    "goAnnotation.evidence.publications.pubMedId",
    "goAnnotation.evidence.publications.citation"
)
query.add_sort_order("Gene.secondaryIdentifier", "ASC")
query.add_constraint("goAnnotation.ontologyTerm", "LOOKUP", "GO:0000182", code = "A")

for row in query.rows():
    print row["primaryIdentifier"], row["secondaryIdentifier"], row["symbol"], row["featureType"], \
        row["goAnnotation.qualifier"], row["goAnnotation.ontologyTerm.identifier"], \
        row["goAnnotation.ontologyTerm.name"], row["goAnnotation.ontologyTerm.namespace"], \
        row["goAnnotation.evidence.code.code"], row["goAnnotation.evidence.code.withText"], \
        row["goAnnotation.evidence.code.annotType"], \
        row["goAnnotation.evidence.publications.pubMedId"], \
        row["goAnnotation.evidence.publications.citation"]
